# %% [markdown]
# # K Means Color Quantization

# %% [markdown]
# ### Imports

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ### The Image

# %%
image_as_array = mpimg.imread('../DATA/palm_trees.jpg')

# %%
image_as_array # RGB CODES FOR EACH PIXEL
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  98],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 106],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 114],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(image_as_array)

# %% [markdown]
# ## Using Kmeans to Quantize Colors
#
# Quantizing colors means we'll reduce the number of unique colors here to K unique colors. Let's try just 6 colors!

# %%
image_as_array.shape
# (h,w,3 color channels)
# Out:
# (1401, 934, 3)

# %% [markdown]
# ### Convert from 3d to 2d
#
# Kmeans is designed to train on 2D data (data rows and feature columns), so we can reshape the above strip by using (h,w,c) ---> (h * w,c)

# %%
(h,w,c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
model
# Out:
# KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0], dtype=int32)

# %%
# THESE ARE THE 6 RGB COLOR CODES!
model.cluster_centers_
# Out:
# array([[  2.77109971,   2.57199445,   3.68235653],
#        [137.02931928, 143.82318971, 143.82158794],
#        [191.79024196, 154.48322658, 109.17559032],
#        [ 71.3298268 , 109.27747552, 137.55355073],
#        [ 67.44115649,  61.70174545,  61.93147553],
#        [219.13999058, 135.36895077,  46.76814089]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [137, 144, 144],
#        [192, 154, 109],
#        [ 71, 109, 138],
#        [ 67,  62,  62],
#        [219, 135,  47]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]])

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(quantized_image)
